# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 1: Load the dataset
df = pd.read_csv("/content/carbon_footprint_results_2000.csv")
df.head()
# Out:
#      Name  Electricity_kWh        Car_km  Short_Haul_Flights  \
# 0  User_1      3621.780832   7851.170512                   3
# 1  User_2      7655.000145   7409.363972                   0
# 2  User_3      6123.957593  27187.637416                   1
# 3  User_4      5190.609389   7486.385995                   2
# 4  User_5      2092.130483   8158.491784                   0
#
#    Long_Haul_Flights  Electricity_Emissions_kg  Car_Emissions_kg  \
# 0                  1               1720.345895       1507.424738
# 1                  0               3636.125069       1422.597883
# 2                  1               2908.879857       5220.026384
# 3                  0               2465.539460       1437.386111
# 4                  0                993.761979       1566.430423
#
#    Flight_Emissions_kg  Total_Emissions_kg  Total_Emissions_tons
# 0                  770         3997.770633              3.997771
# 1                    0         5058.722951              5.058723
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2000 non-null   object
#  1   Electricity_kWh           2000 non-null   float64
#  2   Car_km                    2000 non-null   float64
#  3   Short_Haul_Flights        2000 non-null   int64
#  4   Long_Haul_Flights         2000 non-null   int64
#  5   Electricity_Emissions_kg  2000 non-null   float64
#  6   Car_Emissions_kg          2000 non-null   float64
#  7   Flight_Emissions_kg       2000 non-null   int64
#  8   Total_Emissions_kg        2000 non-null   float64
#  9   Total_Emissions_tons      2000 non-null   float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#        Electricity_kWh        Car_km  Short_Haul_Flights  Long_Haul_Flights  \
# count      2000.000000   2000.000000         2000.000000        2000.000000
# mean       4490.458505  14891.711608            1.425000           0.503000
# std        2045.475589   8657.396852            1.139748           0.712913
# min        1022.527845      0.349043            0.000000           0.000000
# 25%        2666.325302   7523.602769            1.000000           0.000000
# 50%        4551.458899  14780.829829            1.000000           0.000000
# 75%        6254.751815  22460.715295            2.000000           1.000000
# max        7998.023713  29986.731098            6.000000           4.000000
#
#        Electricity_Emissions_kg  Car_Emissions_kg  Flight_Emissions_kg  \
# count               2000.000000       2000.000000          2000.000000
# mean                2132.967790       2859.208629           378.070000
# ...

# %%
df.isnull().sum()
# Out:
# Name                        0
# Electricity_kWh             0
# Car_km                      0
# Short_Haul_Flights          0
# Long_Haul_Flights           0
# Electricity_Emissions_kg    0
# Car_Emissions_kg            0
# Flight_Emissions_kg         0
# Total_Emissions_kg          0
# Total_Emissions_tons        0
# dtype: int64

# %%
sns.histplot(df["Total_Emissions_tons"])
plt.plot()
# Out:
# []

# %%
df.head()
# Out:
#      Name  Electricity_kWh        Car_km  Short_Haul_Flights  \
# 0  User_1      3621.780832   7851.170512                   3
# 1  User_2      7655.000145   7409.363972                   0
# 2  User_3      6123.957593  27187.637416                   1
# 3  User_4      5190.609389   7486.385995                   2
# 4  User_5      2092.130483   8158.491784                   0
#
#    Long_Haul_Flights  Electricity_Emissions_kg  Car_Emissions_kg  \
# 0                  1               1720.345895       1507.424738
# 1                  0               3636.125069       1422.597883
# 2                  1               2908.879857       5220.026384
# 3                  0               2465.539460       1437.386111
# 4                  0                993.761979       1566.430423
#
#    Flight_Emissions_kg  Total_Emissions_kg  Total_Emissions_tons
# 0                  770         3997.770633              3.997771
# 1                    0         5058.722951              5.058723
# ...

# %%
# Step 2: Preprocess Data
# Encode categorical column 'State'
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Name'] = label_encoder.fit_transform(df['Name'])

# %%
df.head()
# Out:
#    Name  Electricity_kWh        Car_km  Short_Haul_Flights  Long_Haul_Flights  \
# 0     0      3621.780832   7851.170512                   3                  1
# 1  1111      7655.000145   7409.363972                   0                  0
# 2  1223      6123.957593  27187.637416                   1                  1
# 3  1334      5190.609389   7486.385995                   2                  0
# 4  1445      2092.130483   8158.491784                   0                  0
#
#    Electricity_Emissions_kg  Car_Emissions_kg  Flight_Emissions_kg  \
# 0               1720.345895       1507.424738                  770
# 1               3636.125069       1422.597883                    0
# 2               2908.879857       5220.026384                  550
# 3               2465.539460       1437.386111                  220
# 4                993.761979       1566.430423                    0
#
#    Total_Emissions_kg  Total_Emissions_tons
# 0         3997.770633              3.997771
# ...

# %%
# Drop Year column as it is not needed
df.drop(columns=["Name"],inplace=True)

# %%
df.head()
# Out:
#    Electricity_kWh        Car_km  Short_Haul_Flights  Long_Haul_Flights  \
# 0      3621.780832   7851.170512                   3                  1
# 1      7655.000145   7409.363972                   0                  0
# 2      6123.957593  27187.637416                   1                  1
# 3      5190.609389   7486.385995                   2                  0
# 4      2092.130483   8158.491784                   0                  0
#
#    Electricity_Emissions_kg  Car_Emissions_kg  Flight_Emissions_kg  \
# 0               1720.345895       1507.424738                  770
# 1               3636.125069       1422.597883                    0
# 2               2908.879857       5220.026384                  550
# 3               2465.539460       1437.386111                  220
# 4                993.761979       1566.430423                    0
#
#    Total_Emissions_kg  Total_Emissions_tons
# 0         3997.770633              3.997771
# ...

# %%
# Step 3: seperate x and y variable

x = df.drop(columns=["Total_Emissions_tons"])  # Features
y = df["Total_Emissions_tons"]  # Target variable
# OR
# x = df.iloc[:,0:6]
# print(x)
# y = df["Total Water Consumption (billion liters)"]  # Target variable
# print(y)

# %%
# Step 4: Split data into training and testing sets (80% train, 20% test)
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Step 5: standardize the data to improve model performance
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
# Step 6: Train the Linear Regression model
# fit function used to train the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
# Step 7: Make predictions
ypred = model.predict(xtest)

# %%
# Step 8: Evaluate the model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

# Print results
print("Mean Absolute Error:", mae) #|y-ypred|
print("Mean Squared Error:", mse)  #(y-ypred)square
print("R-squared Score:", r2) #accuracy
# Out:
# Mean Absolute Error: 1.0458300891968975e-15
# Mean Squared Error: 1.8050123587588276e-30
# R-squared Score: 1.0
